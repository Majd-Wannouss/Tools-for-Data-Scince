# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Majd Wannouss**
# student

# %% [markdown]
# *I am interested in data science because I love this field of science, and I want to enhance my abilities and increase my chances to find the job i always dreamed of*

# %% [markdown]
# ### This code will draw a triangle

# %%
rows = 6
for i in range(rows+1,0,-1):
    for j in range(i-1,rows):
        print(" ",end=' ')
    for j in range(0,i-1):
        print("*",end=' ')
    for j in range(0,i-2):
        print("*",end=' ')
    print("\n")
# Out:
# * * * * * * * * * * *
#
#   * * * * * * * * *
#
#     * * * * * * *
#
#       * * * * *
#
#         * * *
#
#           *

# %% [markdown]
# #### table
#
# ---
# | student name | mark | result
# | --------- |:-----| :-----
# | Mark | 5 | $pass$ |
# | Ben | 2    | $faild$
# | kevin | 4     | $pass$
#
#
# ---
#
# ---
# #### Horizontal Rule
#
# ---
#
# Mark
#
# ---
#
# Ben
#
# ---
#
# Keven
#
# ---
#
# ---
# #### Blockquotes
#
# > I enjoyed this course so much
